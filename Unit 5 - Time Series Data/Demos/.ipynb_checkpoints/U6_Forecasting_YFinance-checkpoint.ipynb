# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

plt.style.use('dark_background')

### IMPORT YF ###
import yfinance as yf

# %% [markdown]
# # Pull data for one stock ticker from Yahoo Finance

# %%
ticker = "MSTR"

start_date = "2000-01-01"
df = yf.download(ticker, start=start_date)
df
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            MSTR        MSTR        MSTR        MSTR      MSTR
# Date
# 2000-01-03  104.250000  115.500000   97.906250  115.500000    535800
# 2000-01-04   98.000000  114.125000   97.875000  104.875000    874600
# 2000-01-05  104.250000  105.875000   89.781250   99.500000    613800
# 2000-01-06  100.125000  108.062500   99.500000  107.500000    456600
# 2000-01-07  105.187500  108.500000   98.625000  102.468750    563000
# ...                ...         ...         ...         ...       ...
# 2025-04-17  317.200012  320.000000  306.000000  313.890015  13472100
# 2025-04-21  317.760010  330.989990  309.000000  324.989990  16053200
# 2025-04-22  343.029999  348.959991  327.010010  328.709991  24036500
# 2025-04-23  345.730011  355.829987  339.000000  354.700012  16648500
# 2025-04-24  346.924988  350.500000  343.240112  345.000000   7777457
#
# [6366 rows x 5 columns]

# %% [markdown]
# # Deal with multi-index columns

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'MSTR'),
#             (  'High', 'MSTR'),
#             (   'Low', 'MSTR'),
#             (  'Open', 'MSTR'),
#             ('Volume', 'MSTR')],
#            names=['Price', 'Ticker'])

# %%
# method 1
#df.columns = df.columns.droplevel(1)

# method 2 (this one is better)
df = df.xs(ticker, axis=1, level=1)
df
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2000-01-03  104.250000  115.500000   97.906250  115.500000    535800
# 2000-01-04   98.000000  114.125000   97.875000  104.875000    874600
# 2000-01-05  104.250000  105.875000   89.781250   99.500000    613800
# 2000-01-06  100.125000  108.062500   99.500000  107.500000    456600
# 2000-01-07  105.187500  108.500000   98.625000  102.468750    563000
# ...                ...         ...         ...         ...       ...
# 2025-04-17  317.200012  320.000000  306.000000  313.890015  13472100
# 2025-04-21  317.760010  330.989990  309.000000  324.989990  16053200
# 2025-04-22  343.029999  348.959991  327.010010  328.709991  24036500
# 2025-04-23  345.730011  355.829987  339.000000  354.700012  16648500
# 2025-04-24  346.924988  350.500000  343.240112  345.000000   7777457
#
# [6366 rows x 5 columns]

# %% [markdown]
# # Basic plotting

# %%
df.Close.plot(figsize=(18,7), linewidth=1, c='g')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Get returns

# %%
returns = df.Close.pct_change(periods=5).dropna()

returns.plot(figsize=(18,7), linewidth=1, c='g')
#returns.rolling(window=5*2).std().plot(c='r')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Create sequences

# %%
# Create lagged sequences
window_size = 10

#perm = np.arange(window_size)
perm = np.random.permutation(np.arange(window_size))

X, y = [], []
dates = []
for i in range(len(returns) - window_size):
    X.append(returns.iloc[i:i+window_size].values[perm])
    y.append(returns.iloc[i+window_size])
    dates.append(returns.index[i+window_size])

X = np.array(X)
y = np.array(y)
dates = np.array(dates)

print(f"X shape: {X.shape}, y shape: {y.shape}")
# Out:
# X shape: (6351, 10), y shape: (6351,)

# %% [markdown]
# # Train / test split (time series)

# %%
# Simple index-based split
split_idx = int(len(X) * 0.8)
X_train, y_train, dates_train = X[:split_idx], y[:split_idx], dates[:split_idx]
X_test, y_test, dates_test = X[split_idx:], y[split_idx:], dates[split_idx:]

print(f"Train: X={X_train.shape}, y={y_train.shape}")
print(f"Test:  X={X_test.shape}, y={y_test.shape}")
# Out:
# Train: X=(5080, 10), y=(5080,)
# Test:  X=(1271, 10), y=(1271,)

# %%
plt.figure(figsize=(7,3))
plt.plot( dates_train, y_train, 'b', label='Train' );
plt.plot( dates_test, y_test, 'r', label='Test' );
plt.legend()

# %% [markdown]
# # Modeling

# %% [markdown]
# ## sklearn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

models = [
    LinearRegression(),
    KNeighborsRegressor(n_neighbors=5, weights='uniform'),
    RandomForestRegressor(n_estimators=100, max_depth=5),
    RandomForestRegressor(n_estimators=100, max_depth=10),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=2),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=5),
]

# %%
from sklearn.metrics import r2_score, mean_squared_error

# Initialize list to hold results
results = []

for m in models:
    m.fit(X_train, y_train)
    
    y_train_pred = m.predict(X_train)
    y_test_pred  = m.predict(X_test)
    
    print(m)
    
    r2_train = r2_score(y_train, y_train_pred)
    print(f'r2_train:   {r2_train:.5}')

    r2_test = r2_score(y_test, y_test_pred)
    print(f'r2_test:    {r2_test:.5}')
    
    rmse_train = mean_squared_error(y_train, y_train_pred)**0.5
    print(f'rmse_train: {rmse_train:.5}')

    rmse_test = mean_squared_error(y_test, y_test_pred)**0.5
    print(f'rmse_test:  {rmse_test:.5}')

    # Store in results list
    results.append({
        'model': str(m),
        'r2_train': r2_train,
        'r2_test': r2_test,
        'rmse_train': rmse_train,
        'rmse_test': rmse_test
    })
    
    y_train_pred = pd.Series(y_train_pred, index=dates_train)
    y_test_pred  = pd.Series(y_test_pred, index=dates_test)

    # Calculate global y-axis limits
    y_min = min(y_train.min(), y_train_pred.min(), y_test.min(), y_test_pred.min())
    y_max = max(y_train.max(), y_train_pred.max(), y_test.max(), y_test_pred.max())

    # Plot train and test side by side with shared y limits
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))

    axs[0].plot(dates_train, y_train, 'r', label='True')
    axs[0].plot(y_train_pred, 'g', label='Predicted')
    axs[0].set_title('Train Set')
    axs[0].set_ylim(y_min, y_max)
    axs[0].legend()

    axs[1].plot(dates_test, y_test, 'r', label='True')
    axs[1].plot(y_test_pred, 'g', label='Predicted')
    axs[1].set_title('Test Set')
    axs[1].set_ylim(y_min, y_max)
    axs[1].legend()

    plt.tight_layout()
    plt.show()

    # Plot train and test side by side with shared y limits
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))

    axs[0].plot(y_train, y_train_pred.values, 'c.')
    axs[0].set_title('Train Set')
    axs[0].legend()

    axs[1].plot(y_test, y_test_pred.values, 'c.')
    axs[1].set_title('Test Set')
    axs[1].legend()

    plt.tight_layout()
    plt.show()
    
    print()
# end

# Create DataFrame
results_df = pd.DataFrame(results)

# Show or sort results
results_df = results_df.set_index("model")
results_df
# Out:
# LinearRegression()
# r2_train:   0.73183
# r2_test:    0.71122
# rmse_train: 0.053055
# rmse_test:  0.074166
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# KNeighborsRegressor()
# r2_train:   0.73152
# r2_test:    0.54505
# rmse_train: 0.053085
# rmse_test:  0.093091
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# RandomForestRegressor(max_depth=5)
# r2_train:   0.76783
# r2_test:    0.62983
# rmse_train: 0.049365
# rmse_test:  0.083971
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# RandomForestRegressor(max_depth=10)
# r2_train:   0.88147
# r2_test:    0.63642
# rmse_train: 0.035271
# rmse_test:  0.083219
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# GradientBoostingRegressor(max_depth=2)
# r2_train:   0.7772
# r2_test:    0.65544
# rmse_train: 0.048359
# rmse_test:  0.081013
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# GradientBoostingRegressor()
# r2_train:   0.84223
# r2_test:    0.67227
# rmse_train: 0.040694
# rmse_test:  0.079011
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# GradientBoostingRegressor(max_depth=5)
# r2_train:   0.92113
# r2_test:    0.65611
# rmse_train: 0.028772
# rmse_test:  0.080936
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
#                                         r2_train   r2_test  rmse_train
# model
# LinearRegression()                      0.731827  0.711225    0.053055  \
# KNeighborsRegressor()                   0.731518  0.545052    0.053085
# RandomForestRegressor(max_depth=5)      0.767832  0.629826    0.049365
# RandomForestRegressor(max_depth=10)     0.881475  0.636424    0.035271
# GradientBoostingRegressor(max_depth=2)  0.777196  0.655444    0.048359
# GradientBoostingRegressor()             0.842230  0.672266    0.040694
# GradientBoostingRegressor(max_depth=5)  0.921131  0.656106    0.028772
#
#                                         rmse_test
# model
# LinearRegression()                       0.074166
# KNeighborsRegressor()                    0.093091
# RandomForestRegressor(max_depth=5)       0.083971
# RandomForestRegressor(max_depth=10)      0.083219
# GradientBoostingRegressor(max_depth=2)   0.081013
# GradientBoostingRegressor()              0.079011
# GradientBoostingRegressor(max_depth=5)   0.080936

# %% [markdown]
# ## Keras

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ### Dense model

# %%
dropout_rate = 0.1

model_dense  = Sequential([
    Input(shape=window_size),
    
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Dense(16, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Dense(8, activation='relu'),
    
    Dense(1, activation='linear'),
])

# Define the optimizer with a custom learning rate
optimizer = Adam(learning_rate=0.01)

# Compile model
model_dense .compile(
    optimizer=optimizer,
    loss='mae',
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

model_dense .summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                352
#
#  batch_normalization (BatchN  (None, 32)               128
#  ormalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  batch_normalization_1 (Batc  (None, 16)               64
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,217
# Trainable params: 1,121
# Non-trainable params: 96
# _________________________________________________________________

# %%
history_dense = model_dense .fit(
    X_train, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_test, y_test),
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 1s 3ms/step - loss: 0.0969 - val_loss: 0.0994
# Epoch 2/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0435 - val_loss: 0.0962
# Epoch 3/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0402 - val_loss: 0.0910
# Epoch 4/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0389 - val_loss: 0.0849
# Epoch 5/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0368 - val_loss: 0.0779
# Epoch 6/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0367 - val_loss: 0.0686
# Epoch 7/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0369 - val_loss: 0.0696
# Epoch 8/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0352 - val_loss: 0.0557
# Epoch 9/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0357 - val_loss: 0.0568
# Epoch 10/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0349 - val_loss: 0.0600
# Epoch 11/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0355 - val_loss: 0.0572
# Epoch 12/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0354 - val_loss: 0.0589
# Epoch 13/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0350 - val_loss: 0.0624
# Epoch 14/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0355 - val_loss: 0.0577
# Epoch 15/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0355 - val_loss: 0.0549
# Epoch 16/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0344 - val_loss: 0.0612
# Epoch 17/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0336 - val_loss: 0.0630
# Epoch 18/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0348 - val_loss: 0.0611
# Epoch 19/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0340 - val_loss: 0.0551
# Epoch 20/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0553
# Epoch 21/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0346 - val_loss: 0.0585
# Epoch 22/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0339 - val_loss: 0.0571
# Epoch 23/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0613
# Epoch 24/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0341 - val_loss: 0.0574
# Epoch 25/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0348 - val_loss: 0.0586
# Epoch 26/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0619
# Epoch 27/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0580
# Epoch 28/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0343 - val_loss: 0.0549
# Epoch 29/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0344 - val_loss: 0.0578
# Epoch 30/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0602
# Epoch 31/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0341 - val_loss: 0.0560
# Epoch 32/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0345 - val_loss: 0.0601
# Epoch 33/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0337 - val_loss: 0.0544
# Epoch 34/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0551
# Epoch 35/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0336 - val_loss: 0.0617
# Epoch 36/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0341 - val_loss: 0.0549
# Epoch 37/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0340 - val_loss: 0.0644
# Epoch 38/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0339 - val_loss: 0.0561
# Epoch 39/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0337 - val_loss: 0.0558
# Epoch 40/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0344 - val_loss: 0.0576
# Epoch 41/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0572
# Epoch 42/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0597
# Epoch 43/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0560
# Epoch 44/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0333 - val_loss: 0.0552
# Epoch 45/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0561
# Epoch 46/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0336 - val_loss: 0.0588
# Epoch 47/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0331 - val_loss: 0.0554
# Epoch 48/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0579
# Epoch 49/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0334 - val_loss: 0.0548
# Epoch 50/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0337 - val_loss: 0.0559
# Epoch 51/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0336 - val_loss: 0.0559
# Epoch 52/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0331 - val_loss: 0.0586
# Epoch 53/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0333 - val_loss: 0.0586
# Epoch 54/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0335 - val_loss: 0.0571
# Epoch 55/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0337 - val_loss: 0.0637
# Epoch 56/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0338 - val_loss: 0.0548
# Epoch 57/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0337 - val_loss: 0.0547
# Epoch 58/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0333 - val_loss: 0.0556

# %%
# Get predictions
y_train_pred = model_dense.predict(X_train)[:,0]
y_test_pred  = model_dense.predict(X_test)[:,0]

# Create a figure with two subplots side by side
fig, ax = plt.subplots(1, 1, figsize=(6, 4))

# Left subplot: Training and Validation Loss
ax.plot(history_dense.history['loss'], label='Training Loss')
ax.plot(history_dense.history['val_loss'], label='Validation Loss')
ax.set_title('Training and Validation Loss')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()

r2_train = r2_score(y_train, y_train_pred)
print(f'r2_train:   {r2_train:.5}')

r2_test = r2_score(y_test, y_test_pred)
print(f'r2_test:    {r2_test:.5}')

rmse_train = mean_squared_error(y_train, y_train_pred)**0.5
print(f'rmse_train: {rmse_train:.5}')

rmse_test = mean_squared_error(y_test, y_test_pred)**0.5
print(f'rmse_test:  {rmse_test:.5}')

y_train_pred = pd.Series(y_train_pred, index=dates_train)
y_test_pred  = pd.Series(y_test_pred, index=dates_test)

# Calculate global y-axis limits
y_min = min(y_train.min(), y_train_pred.min(), y_test.min(), y_test_pred.min())
y_max = max(y_train.max(), y_train_pred.max(), y_test.max(), y_test_pred.max())

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(dates_train, y_train, 'r', label='True')
axs[0].plot(y_train_pred, 'g', label='Predicted')
axs[0].set_title('Train Set')
axs[0].set_ylim(y_min, y_max)
axs[0].legend()

axs[1].plot(dates_test, y_test, 'r', label='True')
axs[1].plot(y_test_pred, 'g', label='Predicted')
axs[1].set_title('Test Set')
axs[1].set_ylim(y_min, y_max)
axs[1].legend()

plt.tight_layout()
plt.show()

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(y_train, y_train_pred.values, 'c.')
axs[0].set_title('Train Set')
axs[0].legend()

axs[1].plot(y_test, y_test_pred.values, 'c.')
axs[1].set_title('Test Set')
axs[1].legend()

plt.tight_layout()
plt.show()
# Out:
# 159/159 [==============================] - 0s 512us/step
# 40/40 [==============================] - 0s 538us/step
# r2_train:   0.52296
# r2_test:    0.6844
# rmse_train: 0.070761
# rmse_test:  0.077535
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ### 1D CNN model

# %%
X_train_2 = X_train.reshape((X_train.shape[0], window_size, 1))
X_test_2 = X_test.reshape((X_test.shape[0], window_size, 1))

model_cnn = Sequential([
    Input(shape=(window_size,1)),
    Conv1D(16, 5, activation='relu', padding='same'),
    Conv1D(16, 5, activation='relu', padding='same'),
    Conv1D(16, 5, activation='relu', padding='same'),
    GlobalMaxPooling1D(),
    Dense(32, activation='relu'),
    Dropout(0.1),
    Dense(8, activation='relu'),
    Dense(1)
])

# Define the optimizer with a custom learning rate
optimizer = Adam(learning_rate=0.001)

# Compile model
model_cnn .compile(
    optimizer=optimizer,
    loss='mae',
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

model_cnn .summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 16)            96
#
#  conv1d_1 (Conv1D)           (None, 10, 16)            1296
#
#  conv1d_2 (Conv1D)           (None, 10, 16)            1296
#
#  global_max_pooling1d (Globa  (None, 16)               0
#  lMaxPooling1D)
#
#  dense_4 (Dense)             (None, 32)                544
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 8)                 264
#
#  dense_6 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 3,505
# Trainable params: 3,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_cnn = model_cnn.fit(
    X_train_2, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_test_2, y_test),
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 1s 3ms/step - loss: 0.0550 - val_loss: 0.0901
# Epoch 2/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0419 - val_loss: 0.0643
# Epoch 3/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0355 - val_loss: 0.0591
# Epoch 4/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0344 - val_loss: 0.0591
# Epoch 5/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0325 - val_loss: 0.0584
# Epoch 6/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0315 - val_loss: 0.0579
# Epoch 7/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0311 - val_loss: 0.0563
# Epoch 8/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0312 - val_loss: 0.0562
# Epoch 9/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0303 - val_loss: 0.0564
# Epoch 10/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0299 - val_loss: 0.0554
# Epoch 11/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0304 - val_loss: 0.0571
# Epoch 12/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0301 - val_loss: 0.0558
# Epoch 13/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0304 - val_loss: 0.0555
# Epoch 14/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0301 - val_loss: 0.0556
# Epoch 15/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0298 - val_loss: 0.0552
# Epoch 16/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0296 - val_loss: 0.0551
# Epoch 17/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0294 - val_loss: 0.0545
# Epoch 18/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0296 - val_loss: 0.0558
# Epoch 19/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0299 - val_loss: 0.0549
# Epoch 20/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0289 - val_loss: 0.0551
# Epoch 21/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0291 - val_loss: 0.0557
# Epoch 22/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0288 - val_loss: 0.0551
# Epoch 23/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0296 - val_loss: 0.0553
# Epoch 24/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0287 - val_loss: 0.0569
# Epoch 25/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0289 - val_loss: 0.0555
# Epoch 26/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0292 - val_loss: 0.0578
# Epoch 27/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0286 - val_loss: 0.0556
# Epoch 28/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0287 - val_loss: 0.0547
# Epoch 29/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0283 - val_loss: 0.0563
# Epoch 30/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0283 - val_loss: 0.0564
# Epoch 31/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0284 - val_loss: 0.0551
# Epoch 32/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0286 - val_loss: 0.0551
# Epoch 33/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0285 - val_loss: 0.0579
# Epoch 34/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0281 - val_loss: 0.0553
# Epoch 35/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0279 - val_loss: 0.0555
# Epoch 36/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0283 - val_loss: 0.0566
# Epoch 37/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0282 - val_loss: 0.0558
# Epoch 38/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0286 - val_loss: 0.0566
# Epoch 39/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0283 - val_loss: 0.0575
# Epoch 40/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0280 - val_loss: 0.0556
# Epoch 41/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0282 - val_loss: 0.0573
# Epoch 42/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0286 - val_loss: 0.0551

# %%
# Get predictions
y_train_pred = model_cnn.predict(X_train)[:,0]
y_test_pred  = model_cnn.predict(X_test)[:,0]

# Create a figure with two subplots side by side
fig, ax = plt.subplots(1, 1, figsize=(6, 4))

# Left subplot: Training and Validation Loss
ax.plot(history_cnn.history['loss'], label='Training Loss')
ax.plot(history_cnn.history['val_loss'], label='Validation Loss')
ax.set_title('Training and Validation Loss')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()

r2_train = r2_score(y_train, y_train_pred)
print(f'r2_train:   {r2_train:.5}')

r2_test = r2_score(y_test, y_test_pred)
print(f'r2_test:    {r2_test:.5}')

rmse_train = mean_squared_error(y_train, y_train_pred)**0.5
print(f'rmse_train: {rmse_train:.5}')

rmse_test = mean_squared_error(y_test, y_test_pred)**0.5
print(f'rmse_test:  {rmse_test:.5}')

y_train_pred = pd.Series(y_train_pred, index=dates_train)
y_test_pred  = pd.Series(y_test_pred, index=dates_test)

# Calculate global y-axis limits
y_min = min(y_train.min(), y_train_pred.min(), y_test.min(), y_test_pred.min())
y_max = max(y_train.max(), y_train_pred.max(), y_test.max(), y_test_pred.max())

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(dates_train, y_train, 'r', label='True')
axs[0].plot(y_train_pred, 'g', label='Predicted')
axs[0].set_title('Train Set')
axs[0].set_ylim(y_min, y_max)
axs[0].legend()

axs[1].plot(dates_test, y_test, 'r', label='True')
axs[1].plot(y_test_pred, 'g', label='Predicted')
axs[1].set_title('Test Set')
axs[1].set_ylim(y_min, y_max)
axs[1].legend()

plt.tight_layout()
plt.show()

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(y_train, y_train_pred.values, 'c.')
axs[0].set_title('Train Set')
axs[0].legend()

axs[1].plot(y_test, y_test_pred.values, 'c.')
axs[1].set_title('Test Set')
axs[1].legend()

plt.tight_layout()
plt.show()
# Out:
# 159/159 [==============================] - 0s 579us/step
# 40/40 [==============================] - 0s 588us/step
# r2_train:   0.75989
# r2_test:    0.69384
# rmse_train: 0.050202
# rmse_test:  0.076367
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ### LSTM model

# %%
X_train_2 = X_train.reshape((X_train.shape[0], window_size, 1))
X_test_2 = X_test.reshape((X_test.shape[0], window_size, 1))

model_lstm = Sequential([
    Input(shape=(window_size, 1)),
    
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    BatchNormalization(),
    
    LSTM(32, return_sequences=False),
    Dropout(0.2),
    
    Dense(32, activation='relu'),
    Dense(1)
])

# Define the optimizer with a custom learning rate
optimizer = Adam(learning_rate=0.001)

# Compile model
model_lstm .compile(
    optimizer=optimizer,
    loss='mae',
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

model_lstm .summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 10, 64)            16896
#
#  dropout_5 (Dropout)         (None, 10, 64)            0
#
#  batch_normalization_3 (Batc  (None, 10, 64)           256
#  hNormalization)
#
#  lstm_6 (LSTM)               (None, 32)                12416
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_13 (Dense)            (None, 32)                1056
#
#  dense_14 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 30,657
# Trainable params: 30,529
# Non-trainable params: 128
# _________________________________________________________________

# %%
history_lstm = model_lstm.fit(
    X_train_2, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_test_2, y_test),
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 4s 13ms/step - loss: 0.0571 - val_loss: 0.1010
# Epoch 2/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0548 - val_loss: 0.1005
# Epoch 3/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0538 - val_loss: 0.1002
# Epoch 4/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0526 - val_loss: 0.0997
# Epoch 5/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0529 - val_loss: 0.0985
# Epoch 6/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0528 - val_loss: 0.0959
# Epoch 7/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0520 - val_loss: 0.0939
# Epoch 8/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0518 - val_loss: 0.0931
# Epoch 9/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0516 - val_loss: 0.0938
# Epoch 10/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0508 - val_loss: 0.0903
# Epoch 11/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0508 - val_loss: 0.0924
# Epoch 12/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0512 - val_loss: 0.0915
# Epoch 13/100
# 80/80 [==============================] - 1s 7ms/step - loss: 0.0503 - val_loss: 0.0912
# Epoch 14/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0505 - val_loss: 0.0908
# Epoch 15/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0504 - val_loss: 0.0904
# Epoch 16/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0501 - val_loss: 0.0908
# Epoch 17/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0496 - val_loss: 0.0915
# Epoch 18/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0499 - val_loss: 0.0894
# Epoch 19/100
# 80/80 [==============================] - 1s 7ms/step - loss: 0.0499 - val_loss: 0.0890
# Epoch 20/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0498 - val_loss: 0.0895
# Epoch 21/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0493 - val_loss: 0.0948
# Epoch 22/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0491 - val_loss: 0.0898
# Epoch 23/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0493 - val_loss: 0.0900
# Epoch 24/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0493 - val_loss: 0.0883
# Epoch 25/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0488 - val_loss: 0.0909
# Epoch 26/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0491 - val_loss: 0.0894
# Epoch 27/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0491 - val_loss: 0.0877
# Epoch 28/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0490 - val_loss: 0.0871
# Epoch 29/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0488 - val_loss: 0.0877
# Epoch 30/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0485 - val_loss: 0.0862
# Epoch 31/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0482 - val_loss: 0.0876
# Epoch 32/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0482 - val_loss: 0.0898
# Epoch 33/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0479 - val_loss: 0.0868
# Epoch 34/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0477 - val_loss: 0.0853
# Epoch 35/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0459 - val_loss: 0.0745
# Epoch 36/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0405 - val_loss: 0.0682
# Epoch 37/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0391 - val_loss: 0.0700
# Epoch 38/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0380 - val_loss: 0.0681
# Epoch 39/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0383 - val_loss: 0.0711
# Epoch 40/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0378 - val_loss: 0.0676
# Epoch 41/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0375 - val_loss: 0.0669
# Epoch 42/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0373 - val_loss: 0.0675
# Epoch 43/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0377 - val_loss: 0.0671
# Epoch 44/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0377 - val_loss: 0.0682
# Epoch 45/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0372 - val_loss: 0.0676
# Epoch 46/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0371 - val_loss: 0.0692
# Epoch 47/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0372 - val_loss: 0.0683
# Epoch 48/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0373 - val_loss: 0.0671
# Epoch 49/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0673
# Epoch 50/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0669
# Epoch 51/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0363 - val_loss: 0.0668
# Epoch 52/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0368 - val_loss: 0.0680
# Epoch 53/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0370 - val_loss: 0.0667
# Epoch 54/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0369 - val_loss: 0.0686
# Epoch 55/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0367 - val_loss: 0.0678
# Epoch 56/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0684
# Epoch 57/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0367 - val_loss: 0.0676
# Epoch 58/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0365 - val_loss: 0.0676
# Epoch 59/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0369 - val_loss: 0.0672
# Epoch 60/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0361 - val_loss: 0.0669
# Epoch 61/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0365 - val_loss: 0.0669
# Epoch 62/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0360 - val_loss: 0.0683
# Epoch 63/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0363 - val_loss: 0.0665
# Epoch 64/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0360 - val_loss: 0.0664
# Epoch 65/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0360 - val_loss: 0.0664
# Epoch 66/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0360 - val_loss: 0.0662
# Epoch 67/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0360 - val_loss: 0.0671
# Epoch 68/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0358 - val_loss: 0.0658
# Epoch 69/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0363 - val_loss: 0.0657
# Epoch 70/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0358 - val_loss: 0.0662
# Epoch 71/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0356 - val_loss: 0.0663
# Epoch 72/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0357 - val_loss: 0.0653
# Epoch 73/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0355 - val_loss: 0.0645
# Epoch 74/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0352 - val_loss: 0.0656
# Epoch 75/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0352 - val_loss: 0.0665
# Epoch 76/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0358 - val_loss: 0.0667
# Epoch 77/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0353 - val_loss: 0.0663
# Epoch 78/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0350 - val_loss: 0.0661
# Epoch 79/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0351 - val_loss: 0.0665
# Epoch 80/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0350 - val_loss: 0.0653
# Epoch 81/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0348 - val_loss: 0.0671
# Epoch 82/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0346 - val_loss: 0.0651
# Epoch 83/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0341 - val_loss: 0.0660
# Epoch 84/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0350 - val_loss: 0.0662
# Epoch 85/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0345 - val_loss: 0.0653
# Epoch 86/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0343 - val_loss: 0.0667
# Epoch 87/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0345 - val_loss: 0.0646
# Epoch 88/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0341 - val_loss: 0.0652
# Epoch 89/100
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0347 - val_loss: 0.0652
# Epoch 90/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0342 - val_loss: 0.0647
# Epoch 91/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0341 - val_loss: 0.0650
# Epoch 92/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0343 - val_loss: 0.0650
# Epoch 93/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0339 - val_loss: 0.0642
# Epoch 94/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0343 - val_loss: 0.0640
# Epoch 95/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0335 - val_loss: 0.0653
# Epoch 96/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0339 - val_loss: 0.0658
# Epoch 97/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0339 - val_loss: 0.0652
# Epoch 98/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0338 - val_loss: 0.0643
# Epoch 99/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0339 - val_loss: 0.0654
# Epoch 100/100
# 80/80 [==============================] - 0s 6ms/step - loss: 0.0341 - val_loss: 0.0656

# %%
# Get predictions
y_train_pred = model_lstm.predict(X_train)[:,0]
y_test_pred  = model_lstm.predict(X_test)[:,0]

# Create a figure with two subplots side by side
fig, ax = plt.subplots(1, 1, figsize=(6, 4))

# Left subplot: Training and Validation Loss
ax.plot(history_lstm.history['loss'], label='Training Loss')
ax.plot(history_lstm.history['val_loss'], label='Validation Loss')
ax.set_title('Training and Validation Loss')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()

r2_train = r2_score(y_train, y_train_pred)
print(f'r2_train:   {r2_train:.5}')

r2_test = r2_score(y_test, y_test_pred)
print(f'r2_test:    {r2_test:.5}')

rmse_train = mean_squared_error(y_train, y_train_pred)**0.5
print(f'rmse_train: {rmse_train:.5}')

rmse_test = mean_squared_error(y_test, y_test_pred)**0.5
print(f'rmse_test:  {rmse_test:.5}')

y_train_pred = pd.Series(y_train_pred, index=dates_train)
y_test_pred  = pd.Series(y_test_pred, index=dates_test)

# Calculate global y-axis limits
y_min = min(y_train.min(), y_train_pred.min(), y_test.min(), y_test_pred.min())
y_max = max(y_train.max(), y_train_pred.max(), y_test.max(), y_test_pred.max())

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(dates_train, y_train, 'r', label='True')
axs[0].plot(y_train_pred, 'g', label='Predicted')
axs[0].set_title('Train Set')
axs[0].set_ylim(y_min, y_max)
axs[0].legend()

axs[1].plot(dates_test, y_test, 'r', label='True')
axs[1].plot(y_test_pred, 'g', label='Predicted')
axs[1].set_title('Test Set')
axs[1].set_ylim(y_min, y_max)
axs[1].legend()

plt.tight_layout()
plt.show()

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(y_train, y_train_pred.values, 'c.')
axs[0].set_title('Train Set')
axs[0].legend()

axs[1].plot(y_test, y_test_pred.values, 'c.')
axs[1].set_title('Test Set')
axs[1].legend()

plt.tight_layout()
plt.show()
# Out:
# 159/159 [==============================] - 1s 2ms/step
# 40/40 [==============================] - 0s 2ms/step
# r2_train:   0.73601
# r2_test:    0.56493
# rmse_train: 0.052639
# rmse_test:  0.091035
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
