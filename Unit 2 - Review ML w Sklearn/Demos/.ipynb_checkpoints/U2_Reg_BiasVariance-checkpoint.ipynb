# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import r2_score

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

plt.style.use('dark_background')

# %% [markdown]
# # A simple polyfit example

# %%
nPts = 10

x = np.linspace(0, 3, nPts)
y = x**2 + np.random.normal(0, 0.5, nPts)

# %%
degree = 9
coef = np.polyfit(x, y, degree)
print("coef:", coef)

poly_function = np.poly1d(coef)
pred  = poly_function(x)
error = ((y-pred)**2).sum()
print("error:", error)
print("r^2:", r2_score(y,pred))

x_values = np.linspace(-4, 4, 100)
y_values = poly_function(x_values)

plt.scatter(x, y, label='Data')
plt.plot(x_values, y_values, label='polyfit (degree 2)', color='red')

plt.xlim(-5,5);
plt.ylim(-2,18);
plt.legend();
# Out:
# coef: [-8.99476560e+00  1.21035087e+02 -6.86307268e+02  2.13258948e+03
#  -3.95045114e+03  4.43581950e+03 -2.91925487e+03  1.01441817e+03
#  -1.38123649e+02 -1.04643620e-02]
# error: 1.2946031651533547e-18
# r^2: 1.0

# %% [markdown]
# # Getting some stats

# %%
nPts  = 10
nSamp = 10

data = []
for d in range(1,10):
    samp = []
    for i in range(nSamp):
        x = np.linspace(0, 3, nPts)
        y = x**2 + np.random.normal(0, 0.5, nPts)

        coef  = np.polyfit(x, y, d)
        poly_function = np.poly1d(coef)
        pred  = poly_function(x)
        error = ((y-pred)**2).sum()
        r2 = r2_score(y,pred)
        coef = np.append(coef, [error, r2])
        coef = np.flip(coef)
        
        samp.append(coef)
    # end
    data.append(samp)
# end

dfs = []
for i,d in enumerate(data):
    cols = ['r^2', 'error'] + list(range(i+2))
    df = pd.DataFrame(d, columns=cols)
    dfs.append(df)
    display(df.describe().iloc[1:3])
# end
# Out:
#            r^2     error         0         1
# mean  0.908569  8.581108 -1.449427  3.062987
# std   0.022860  1.991980  0.153191  0.185814
#            r^2     error         0         1        2
# mean  0.973363  2.385538  0.123974 -0.075250  1.00889
# std   0.016785  1.522865  0.372974  0.570959  0.19479
#            r^2     error         0         1         2         3
# mean  0.985347  1.332974 -0.156908  0.053492  1.132624 -0.047136
# std   0.006201  0.519500  0.426333  0.996578  0.880711  0.213938
#            r^2     error         0        1         2         3         4
# mean  0.985366  1.448935 -0.180694  0.74045 -0.512839  0.938071 -0.170329
# std   0.007673  0.862907  0.335212  3.02271  4.521808  2.258970  0.364403
#            r^2     error         0         1          2          3         4  \
# mean  0.988219  1.048563  0.191529 -0.010077   0.756812   0.460484 -0.271019
# std   0.010479  0.935926  0.532649  6.298239  14.762608  12.910918  4.753427
#
#              5
# mean  0.048431
# std   0.621257
#            r^2     error         0         1          2          3          4  \
# mean  0.990732  0.825013 -0.192052  0.767495   3.068398  -6.028730   4.777711
# std   0.005330  0.490727  0.541217  6.465349  17.851175  20.950446  12.206800
#
#              5         6
# mean -1.546643  0.179521
# std   3.472316  0.383049
#            r^2     error         0          1          2           3  \
# mean  0.995684  0.400260  0.217788  -0.903543   1.537300    1.713556
# std   0.003800  0.367974  0.355365  12.422132  58.419563  108.831464
#
#                4          5          6         7
# mean   -3.455295   2.549842  -0.827014  0.098163
# std   100.319019  48.507856  11.769918  1.129229
#            r^2     error         0          1           2           3  \
# mean  0.996742  0.287709 -0.198404   8.542144  -48.055912  109.091066
# std   0.004175  0.362463  0.688929  17.712877  116.602111  294.781670
#
#                4           5           6          7         8
# mean -122.434125   76.518361  -27.079718   5.085269 -0.394271
# std   373.280659  260.435679  101.613112  20.766916  1.730515
#       r^2         error         0          1           2            3  \
# mean  1.0  3.437354e-19 -0.282850  10.736073  -56.481699   126.248660
# std   0.0  5.997065e-19  0.309459  62.115735  480.838114  1454.236508
#
#                 4            5            6           7         8         9
# mean  -141.352891    85.738915   -26.996451    3.236976   0.26392 -0.073100
# std   2298.169476  2109.579569  1165.001602  381.224842  68.03733  5.097867
