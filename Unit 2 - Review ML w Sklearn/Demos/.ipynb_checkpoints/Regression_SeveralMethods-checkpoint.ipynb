# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

plt.style.use('dark_background')

# %% [markdown]
# # Create data

# %%
markersize = 6

nPts = 1000

m = 1
b = 0

x = np.linspace(-3, 3, nPts)
#y = m*x + b + np.random.normal(0, 0.5, nPts)
#y = 0.5*x**2 - 2 + np.random.normal(0, 0.3, nPts)
y = np.sin(2*np.pi*x/4) + np.random.normal(0, 0.3, nPts)

X = x[:,np.newaxis]

plt.scatter(x, y, label='Data', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.gca().set_aspect('equal')

# %% [markdown]
# # Train/test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

X_ext = np.linspace(-5, 5, 1000)[:,np.newaxis]

plt.scatter(X_train[:,0], y_train, label='Training Data', c='c', s=markersize);
plt.scatter(X_test[:,0], y_test, label='Testing Data', c='r', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.gca().set_aspect('equal')

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression

model1 = LinearRegression()
model1.fit(X_train, y_train)

y_train_pred_lin = model1.predict(X_train)
y_test_pred_lin  = model1.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

# r^2
r2_train = r2_score(y_train, y_train_pred_lin)
print(f'r^2 (train):  {r2_train}')

r2_test = r2_score(y_test, y_test_pred_lin)
print(f'r^2 (test):   {r2_test}')
print()

# MSE
mse_train = mean_squared_error(y_train, y_train_pred_lin)
print(f'MSE (train):  {mse_train}')

mse_test = mean_squared_error(y_test, y_test_pred_lin)
print(f'MSE (test):   {mse_test}')
print()

# RMSE
rmse_train = sqrt(mse_train)
print(f'RMSE (train): {rmse_train}')

rmse_test = sqrt(mse_test)
print(f'RMSE (test):  {rmse_test}')
print()
# Out:
# r^2 (train):  0.01439917486449016
# r^2 (test):   -0.02533114707438311
#
# MSE (train):  0.5746026089114363
# MSE (test):   0.5432005396785138
#
# RMSE (train): 0.7580254671918591
# RMSE (test):  0.7370213970289559

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.scatter(X_train[:,0], y_train, label='Training Data', c='c', s=markersize);
plt.scatter(X_train[:,0], y_train_pred_lin, label='Training Data', c='m', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Training data')
plt.gca().set_aspect('equal')

plt.subplot(132)
plt.scatter(X_test[:,0], y_test, label='Testing Data', c='r', s=markersize);
plt.scatter(X_test[:,0], y_test_pred_lin, label='Testing Data', c='m', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Testing data')
plt.gca().set_aspect('equal')

plt.subplot(133)
plt.scatter(X_train[:,0], y_train, label='Training Data', c='c', s=markersize);
plt.plot(X_ext[:,0], model1.predict(X_ext), 'm');
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Interp/Extrap')
plt.gca().set_aspect('equal')

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor

nNeigh = 25

#model2 = KNeighborsRegressor(n_neighbors=nNeigh)
model2 = KNeighborsRegressor(n_neighbors=nNeigh,weights='uniform')
#model2 = KNeighborsRegressor(n_neighbors=nNeigh,weights='distance')

model2.fit(X_train, y_train)

y_train_pred_knn = model2.predict(X_train)
y_test_pred_knn  = model2.predict(X_test)

# %%
# r^2
r2_train = r2_score(y_train, y_train_pred_knn)
print(f'r^2 (train):  {r2_train}')

r2_test = r2_score(y_test, y_test_pred_knn)
print(f'r^2 (test):   {r2_test}')
print()

# MSE
mse_train = mean_squared_error(y_train, y_train_pred_knn)
print(f'MSE (train):  {mse_train}')

mse_test = mean_squared_error(y_test, y_test_pred_knn)
print(f'MSE (test):   {mse_test}')
print()

# RMSE
rmse_train = sqrt(mse_train)
print(f'RMSE (train): {rmse_train}')

rmse_test = sqrt(mse_test)
print(f'RMSE (test):  {rmse_test}')
print()
# Out:
# r^2 (train):  0.8590984864200513
# r^2 (test):   0.8192868812504579
#
# MSE (train):  0.08214520040755566
# MSE (test):   0.09573830260773039
#
# RMSE (train): 0.2866098400396533
# RMSE (test):  0.309416067145406

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.scatter(X_train[:,0], y_train, label='Training Data', c='c', s=markersize);
plt.scatter(X_train[:,0], y_train_pred_knn, label='Training Data', c='m', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Training data')
plt.gca().set_aspect('equal')

plt.subplot(132)
plt.scatter(X_test[:,0], y_test, label='Testing Data', c='r', s=markersize);
plt.scatter(X_test[:,0], y_test_pred_knn, label='Testing Data', c='m', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Testing data')
plt.gca().set_aspect('equal')

plt.subplot(133)
plt.scatter(X_train[:,0], y_train, label='Training Data', c='c', s=markersize);
plt.plot(X_ext[:,0], model2.predict(X_ext), 'm');
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Interp/Extrap')
plt.gca().set_aspect('equal')

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

model3 = DecisionTreeRegressor(max_depth=2)
#model3 = DecisionTreeRegressor(min_samples_split=3)
#model3 = DecisionTreeRegressor()
model3.fit(X_train, y_train)

y_train_pred_tree = model3.predict(X_train)
y_test_pred_tree  = model3.predict(X_test)

plt.figure(figsize=(10,5))
#plot_tree(model3, rounded=True, fontsize=10);
plot_tree(model3);

# %%
# r^2
r2_train = r2_score(y_train, y_train_pred_tree)
print(f'r^2 (train):  {r2_train}')

r2_test = r2_score(y_test, y_test_pred_tree)
print(f'r^2 (test):   {r2_test}')
print()

# MSE
mse_train = mean_squared_error(y_train, y_train_pred_tree)
print(f'MSE (train):  {mse_train}')

mse_test = mean_squared_error(y_test, y_test_pred_tree)
print(f'MSE (test):   {mse_test}')
print()

# RMSE
rmse_train = sqrt(mse_train)
print(f'RMSE (train): {rmse_train}')

rmse_test = sqrt(mse_test)
print(f'RMSE (test):  {rmse_test}')
print()
# Out:
# r^2 (train):  0.8603730870419339
# r^2 (test):   0.7799767338950753
#
# MSE (train):  0.08140211170067153
# MSE (test):   0.11656405565269924
#
# RMSE (train): 0.28531055308325265
# RMSE (test):  0.3414147853457715

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.scatter(X_train[:,0], y_train, label='Training Data', c='c', s=markersize);
plt.scatter(X_train[:,0], y_train_pred_tree, label='Training Data', c='m', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Training data')
plt.gca().set_aspect('equal')

plt.subplot(132)
plt.scatter(X_test[:,0], y_test, label='Testing Data', c='r', s=markersize);
plt.scatter(X_test[:,0], y_test_pred_tree, label='Testing Data', c='m', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Testing data')
plt.gca().set_aspect('equal')

plt.subplot(133)
plt.scatter(X_train[:,0], y_train, label='Training Data', c='c', s=markersize);
plt.plot(X_ext[:,0], model3.predict(X_ext), 'm');
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Interp/Extrap')
plt.gca().set_aspect('equal')

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

#model4 = RandomForestRegressor()
model4 = RandomForestRegressor(n_estimators=100, max_depth=5)
#model4 = RandomForestRegressor(n_estimators=100, min_samples_split=3)
model4.fit(X_train, y_train)

y_train_pred_forest = model4.predict(X_train)
y_test_pred_forest = model4.predict(X_test)

# %%
# r^2
r2_train = r2_score(y_train, y_train_pred_forest)
print(f'r^2 (train):  {r2_train}')

r2_test = r2_score(y_test, y_test_pred_forest)
print(f'r^2 (test):   {r2_test}')
print()

# MSE
mse_train = mean_squared_error(y_train, y_train_pred_forest)
print(f'MSE (train):  {mse_train}')

mse_test = mean_squared_error(y_test, y_test_pred_forest)
print(f'MSE (test):   {mse_test}')
print()

# RMSE
rmse_train = sqrt(mse_train)
print(f'RMSE (train): {rmse_train}')

rmse_test = sqrt(mse_test)
print(f'RMSE (test):  {rmse_test}')
print()
# Out:
# r^2 (train):  0.8706414441420524
# r^2 (test):   0.8091113727621689
#
# MSE (train):  0.07541568735068063
# MSE (test):   0.10112908949459447
#
# RMSE (train): 0.2746191678500986
# RMSE (test):  0.31800800224930575

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.scatter(X_train[:,0], y_train, label='Training Data', c='c', s=markersize);
plt.scatter(X_train[:,0], y_train_pred_forest, label='Training Data', c='m', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Training data')
plt.gca().set_aspect('equal')

plt.subplot(132)
plt.scatter(X_test[:,0], y_test, label='Testing Data', c='r', s=markersize);
plt.scatter(X_test[:,0], y_test_pred_forest, label='Testing Data', c='m', s=markersize);
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Testing data')
plt.gca().set_aspect('equal')

plt.subplot(133)
plt.scatter(X_train[:,0], y_train, label='Training Data', c='c', s=markersize);
plt.plot(X_ext[:,0], model4.predict(X_ext), 'm');
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.title('Interp/Extrap')
plt.gca().set_aspect('equal')
