# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('dark_background')

# %% [markdown]
# # Create data

# %%
nPts = 1000

m = 0.5
b = 1

x = np.linspace(-2, 2, nPts)
X = x[:, np.newaxis]

#y = m*x + b
#y = x**2
y = np.sin(2*np.pi*x/2)

y += np.random.normal(0, 0.1, nPts)

plt.figure(figsize=(10, 6))
plt.scatter(x, y, label='Data')
plt.show()

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Train / test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

x_ext = np.linspace(-4, 4, nPts)

markersize = 10
plt.scatter(X_train[:,0], y_train, label='Training Data', c='b', s=markersize);
plt.scatter(X_test[:,0], y_test, label='Testing Data', c='r', s=markersize);
plt.legend()

# %% [markdown]
# ### Create and train models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor

models = [
    LinearRegression(),
    KNeighborsRegressor(n_neighbors=1, weights='uniform'),
    KNeighborsRegressor(n_neighbors=10, weights='uniform'),
    KNeighborsRegressor(n_neighbors=100, weights='uniform'),
    DecisionTreeRegressor(max_depth=2),
    DecisionTreeRegressor(max_depth=5),
    DecisionTreeRegressor(max_depth=10),
    RandomForestRegressor(n_estimators=10, max_depth=5),
    RandomForestRegressor(n_estimators=100, max_depth=10),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=2),
    MLPRegressor(hidden_layer_sizes=(30,20,10), max_iter=1000, tol=0.00001, n_iter_no_change=10)
]

# %%
from sklearn.metrics import r2_score, mean_squared_error

for m in models:
    m.fit(X_train, y_train)
    
    y_train_pred = m.predict(X_train)
    y_test_pred  = m.predict(X_test)
    y_ext_pred   = m.predict(x_ext[:, np.newaxis])
    
    print(m)
    
    r2_train = r2_score(y_train, y_train_pred)
    print(f' r2_train:   {r2_train:.5}')

    r2_test = r2_score(y_test, y_test_pred)
    print(f' r2_test:    {r2_test:.5}')
    
    rmse_train = mean_squared_error(y_train, y_train_pred)
    print(f' rmse_train: {rmse_train:.5}')

    rmse_test = mean_squared_error(y_test, y_test_pred)
    print(f' rmse_test:  {rmse_test:.5}')
    
    # Create side-by-side subplots
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    
    # Training set plot
    axes[0].scatter(X_train, y_train, color='red', label='Actual')
    axes[0].scatter(X_train, y_train_pred, color='green', label='Predicted')
    axes[0].set_title('Training Set')
    axes[0].set_xlabel('X_train')
    axes[0].set_ylabel('y_train')
    axes[0].legend()
    
    # Test set plot
    axes[1].scatter(X_test, y_test, color='red', label='Actual')
    axes[1].scatter(X_test, y_test_pred, color='green', label='Predicted')
    axes[1].set_title('Test Set')
    axes[1].set_xlabel('X_test')
    axes[1].set_ylabel('y_test')
    axes[1].legend()
    
    # Extrapolation plot
    axes[2].scatter(x, y, color='red', label='Original')
    axes[2].scatter(x_ext, y_ext_pred, color='green', label='Extrapolated')
    axes[2].set_title('Extrapolation Set')
    axes[2].set_xlabel('x_ext')
    axes[2].set_ylabel('y')
    axes[2].legend()
    
    fig.suptitle(f'Model: {m.__class__.__name__}', fontsize=14)
    plt.tight_layout()
    plt.show()
    print()
# end
# Out:
# LinearRegression()
#  r2_train:   0.16061
#  r2_test:    0.1025
#  rmse_train: 0.43393
#  rmse_test:  0.42496
# KNeighborsRegressor(n_neighbors=1)
#  r2_train:   1.0
#  r2_test:    0.96514
#  rmse_train: 0.0
#  rmse_test:  0.016508
# KNeighborsRegressor(n_neighbors=10)
#  r2_train:   0.98302
#  r2_test:    0.9797
#  rmse_train: 0.0087779
#  rmse_test:  0.0096124
# KNeighborsRegressor(n_neighbors=100)
#  r2_train:   0.9462
#  r2_test:    0.94498
#  rmse_train: 0.027813
#  rmse_test:  0.026051
# DecisionTreeRegressor(max_depth=2)
#  r2_train:   0.44469
#  r2_test:    0.40938
#  rmse_train: 0.28707
#  rmse_test:  0.27965
# DecisionTreeRegressor(max_depth=5)
#  r2_train:   0.95714
#  r2_test:    0.94218
#  rmse_train: 0.022157
#  rmse_test:  0.02738
# DecisionTreeRegressor(max_depth=10)
#  r2_train:   0.99297
#  r2_test:    0.97224
#  rmse_train: 0.0036353
#  rmse_test:  0.013146
# RandomForestRegressor(max_depth=5, n_estimators=10)
#  r2_train:   0.9731
#  r2_test:    0.96684
#  rmse_train: 0.013907
#  rmse_test:  0.015702
# RandomForestRegressor(max_depth=10)
#  r2_train:   0.99266
#  r2_test:    0.97682
#  rmse_train: 0.003793
#  rmse_test:  0.010978
# GradientBoostingRegressor(max_depth=2)
#  r2_train:   0.98533
#  r2_test:    0.97716
#  rmse_train: 0.0075854
#  rmse_test:  0.010815
# MLPRegressor(hidden_layer_sizes=(30, 20, 10), max_iter=1000, tol=1e-05)
#  r2_train:   0.98201
#  r2_test:    0.97856
#  rmse_train: 0.0093019
#  rmse_test:  0.010153

# %% [markdown]
# ### Cross validation

# %%
from sklearn.model_selection import cross_val_score, KFold

kf = KFold(n_splits=5, shuffle=True)

for m in models:
    print(m)
    
    cv_scores = cross_val_score(m, X, y, cv=kf, scoring='r2')
    cv_scores = pd.DataFrame(cv_scores)
    display(cv_scores.describe().T)
# end
# Out:
# LinearRegression()
#    count     mean       std       min       25%      50%       75%       max
# 0    5.0  0.13972  0.061235  0.039898  0.135048  0.14914  0.173036  0.201477
# KNeighborsRegressor(n_neighbors=1)
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0  0.967064  0.002902  0.963627  0.965463  0.966447  0.968677  0.971104
# KNeighborsRegressor(n_neighbors=10)
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0  0.979186  0.002663  0.975429  0.977417  0.980229  0.981415  0.981438
# KNeighborsRegressor(n_neighbors=100)
#    count     mean       std       min       25%       50%       75%      max
# 0    5.0  0.94188  0.013634  0.928364  0.930078  0.940255  0.950065  0.96064
# DecisionTreeRegressor(max_depth=2)
#    count      mean       std       min      25%       50%       75%       max
# 0    5.0  0.406423  0.033579  0.364355  0.38281  0.415577  0.418849  0.450523
# DecisionTreeRegressor(max_depth=5)
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0  0.948532  0.005389  0.942952  0.944704  0.946499  0.953636  0.954871
# DecisionTreeRegressor(max_depth=10)
#    count      mean       std       min       25%       50%      75%       max
# 0    5.0  0.969409  0.004796  0.961907  0.967771  0.970682  0.97284  0.973843
# RandomForestRegressor(max_depth=5, n_estimators=10)
#    count      mean       std      min      25%       50%      75%       max
# 0    5.0  0.963022  0.002697  0.95943  0.96222  0.962586  0.96408  0.966796
# RandomForestRegressor(max_depth=10)
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0  0.976473  0.001773  0.973651  0.975837  0.977276  0.977679  0.977923
# GradientBoostingRegressor(max_depth=2)
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0  0.977156  0.002025  0.974099  0.976258  0.977869  0.978287  0.979268
# MLPRegressor(hidden_layer_sizes=(30, 20, 10), max_iter=1000, tol=1e-05)
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0  0.978518  0.001806  0.975935  0.977867  0.978369  0.979896  0.980524
